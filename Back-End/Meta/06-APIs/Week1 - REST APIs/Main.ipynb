# %% [markdown]
# ### **course introduction**

# %% [markdown]
# ![](2024-08-10-23-34-58.png)

# %% [markdown]
# ![](2024-08-10-23-35-24.png)

# %% [markdown]
# ![](2024-08-10-23-36-09.png)

# %% [markdown]
# ![](2024-08-10-23-36-34.png)

# %% [markdown]
# ![](2024-08-10-23-36-58.png)

# %% [markdown]
# ![](2024-08-10-23-37-25.png)

# %% [markdown]
# ### **introduction to apis**

# %% [markdown]
# #### **what-you-know-about-http**

# %% [markdown]
# ![](2024-08-10-23-48-41.png)

# %% [markdown]
# ![](2024-08-10-23-49-33.png)

# %% [markdown]
# ![](2024-08-10-23-50-35.png)

# %% [markdown]
# > HTTP Request

# %% [markdown]
# ![](2024-08-10-23-51-05.png)

# %% [markdown]
# ![](2024-08-10-23-51-43.png)

# %% [markdown]
# ![](2024-08-10-23-52-01.png)

# %% [markdown]
# > HTTP Response

# %% [markdown]
# ![](2024-08-10-23-52-52.png)

# %% [markdown]
# ![](2024-08-10-23-53-19.png)

# %% [markdown]
# ![](2024-08-10-23-54-08.png)

# %% [markdown]
# ![](2024-08-10-23-55-08.png)

# %% [markdown]
# ![](2024-08-10-23-55-37.png)

# %% [markdown]
# ![](2024-08-10-23-56-18.png)

# %% [markdown]
# ![](2024-08-10-23-56-48.png)

# %% [markdown]
# ![](2024-08-10-23-57-17.png)

# %% [markdown]
# #### **restfulness**

# %% [markdown]
# ![](2024-08-10-23-58-56.png)

# %% [markdown]
# ![](2024-08-10-23-59-49.png)

# %% [markdown]
# ![](2024-08-11-00-00-35.png)

# %% [markdown]
# ![](2024-08-11-00-01-13.png)

# %% [markdown]
# ![](2024-08-11-00-01-55.png)

# %% [markdown]
# ![](2024-08-11-00-08-54.png)

# %% [markdown]
# ![](2024-08-11-00-06-31.png)

# %% [markdown]
# ![](2024-08-11-00-09-30.png)

# %% [markdown]
# ![](2024-08-11-00-10-32.png)

# %% [markdown]
# ![](2024-08-11-00-10-56.png)

# %% [markdown]
# ![](2024-08-11-00-11-19.png)

# %% [markdown]
# ![](2024-08-11-00-13-01.png)

# %% [markdown]
# ![](2024-08-11-00-13-43.png)

# %% [markdown]
# ![](2024-08-11-00-14-19.png)

# %% [markdown]
# ![](2024-08-11-00-14-57.png)

# %% [markdown]
# > Let's assume there is an app for the little lemon restaurant ...

# %% [markdown]
# ![](2024-08-11-00-16-25.png)

# %% [markdown]
# ![](2024-08-11-00-19-08.png)

# %% [markdown]
# ![](2024-08-11-00-19-54.png)

# %% [markdown]
# ![](2024-08-11-00-26-41.png)

# %% [markdown]
# ![](2024-08-11-00-27-17.png)

# %% [markdown]
# ![](2024-08-11-00-27-41.png)

# %% [markdown]
# ![](2024-08-11-00-28-22.png)

# %% [markdown]
# ![](2024-08-11-00-29-23.png)

# %% [markdown]
# #### **naming-conventions**

# %% [markdown]
# ![](2024-08-11-00-30-42.png)

# %% [markdown]
# ![](2024-08-11-00-31-32.png)

# %% [markdown]
# ![](2024-08-11-00-31-57.png)

# %% [markdown]
# ![](2024-08-11-00-32-15.png)

# %% [markdown]
# > An API variable, on the other hand, should be placed in side {} with camel-case.

# %% [markdown]
# ![](2024-08-11-00-33-19.png)

# %% [markdown]
#  ![](2024-08-11-00-35-27.png)

# %% [markdown]
# ![](2024-08-11-00-36-48.png)

# %% [markdown]
# ![](2024-08-11-00-37-54.png)

# %% [markdown]
# ![](2024-08-11-00-40-33.png)

# %% [markdown]
# ![](2024-08-11-00-41-10.png)

# %% [markdown]
# ![](2024-08-11-00-41-42.png)

# %% [markdown]
# ![](2024-08-11-00-43-40.png)

# %% [markdown]
# ![](2024-08-11-00-44-16.png)

# %% [markdown]
# ![](2024-08-11-00-46-26.png)

# %% [markdown]
# ![](2024-08-11-00-47-08.png)

# %% [markdown]
# ![](2024-08-11-00-48-10.png)

# %% [markdown]
# ![](2024-08-11-00-48-38.png)

# %% [markdown]
# ![](2024-08-11-00-50-47.png)

# %% [markdown]
# ![](2024-08-11-00-51-24.png)

# %% [markdown]
# ![](2024-08-11-00-52-11.png)

# %% [markdown]
# ![](2024-08-11-00-52-37.png)

# %% [markdown]
# ![](2024-08-11-00-53-54.png)

# %% [markdown]
# ![](2024-08-11-00-55-48.png)

# %% [markdown]
# ![](2024-08-11-00-56-20.png)

# %% [markdown]
# #### **essential-tools-for-api-development**

# %% [markdown]
# ![](2024-08-11-01-26-40.png)

# %% [markdown]
# ![](2024-08-11-01-27-04.png)

# %% [markdown]
# ![](2024-08-11-01-27-34.png)

# %% [markdown]
# ![](2024-08-11-01-28-31.png)

# %% [markdown]
# ![](2024-08-11-01-29-21.png)

# %% [markdown]
# ![](2024-08-11-01-29-41.png)

# %% [markdown]
# ![](2024-08-11-01-30-09.png)

# %% [markdown]
# ![](2024-08-11-01-33-46.png)

# %% [markdown]
# ![](2024-08-11-01-37-25.png)

# %% [markdown]
# ![](2024-08-11-01-38-12.png)

# %% [markdown]
# ![](2024-08-11-01-38-34.png)

# %% [markdown]
# ![](2024-08-11-01-41-16.png)

# %% [markdown]
# ![](2024-08-11-01-44-14.png)

# %% [markdown]
# ![](2024-08-11-01-47-01.png)

# %% [markdown]
# ![](2024-08-11-01-47-56.png)

# %% [markdown]
# ![](2024-08-11-01-49-01.png)

# %% [markdown]
# ![](2024-08-11-01-59-07.png)

# %% [markdown]
# #### **create-a-django-project-using-pipenv**

# %% [markdown]
# ![](2024-08-11-02-03-26.png)

# %% [markdown]
# ![](2024-08-11-02-04-15.png)

# %% [markdown]
# > \>pipenv shell

# %% [markdown]
# ![](2024-08-11-02-10-04.png)

# %% [markdown]
# ![](2024-08-11-02-14-57.png)

# %% [markdown]
# ![](2024-08-11-02-15-30.png)

# %% [markdown]
# > to run with a different port number ...

# %% [markdown]
# ![](2024-08-11-02-17-04.png)

# %% [markdown]
# > pipenv shell

# %% [markdown]
# > Ctrl+Shift+P

# %% [markdown]
# ![](2024-08-11-02-21-29.png)

# %% [markdown]
# ### **principles of api development**

# %% [markdown]
# #### **rest-best-practices**

# %% [markdown]
# > KISS

# %% [markdown]
# ![](2024-08-11-02-55-26.png)

# %% [markdown]
# ![](2024-08-11-02-55-43.png)

# %% [markdown]
# ![](2024-08-11-02-56-30.png)

# %% [markdown]
# ![](2024-08-11-02-58-02.png)

# %% [markdown]
# ![](2024-08-11-02-59-00.png)

# %% [markdown]
# ![](2024-08-11-03-00-16.png)

# %% [markdown]
# ![](2024-08-11-03-00-49.png)

# %% [markdown]
# ![](2024-08-11-03-01-59.png)

# %% [markdown]
# ![](2024-08-11-03-03-25.png)

# %% [markdown]
# ![](2024-08-11-03-03-58.png)

# %% [markdown]
# ![](2024-08-11-03-04-34.png)

# %% [markdown]
# ![](2024-08-11-03-05-01.png)

# %% [markdown]
# ![](2024-08-11-03-05-30.png)

# %% [markdown]
# ![](2024-08-11-03-05-57.png)

# %% [markdown]
# ![](2024-08-11-03-06-15.png)

# %% [markdown]
# ![](2024-08-11-03-06-38.png)

# %% [markdown]
# #### **security-and-authentication-in-rest-api**

# %% [markdown]
# ![](2024-08-11-03-38-18.png)

# %% [markdown]
# ![](2024-08-11-03-38-57.png)

# %% [markdown]
# ![](2024-08-11-03-39-44.png)

# %% [markdown]
# ![](2024-08-11-03-40-07.png)

# %% [markdown]
# ![](2024-08-11-03-40-31.png)

# %% [markdown]
# ![](2024-08-11-03-41-06.png)

# %% [markdown]
# ![](2024-08-11-03-41-33.png)

# %% [markdown]
# ![](2024-08-11-03-41-53.png)

# %% [markdown]
# ![](2024-08-11-03-42-20.png)

# %% [markdown]
# ![](2024-08-11-03-42-51.png)

# %% [markdown]
# ![](2024-08-11-03-43-20.png)

# %% [markdown]
# ![](2024-08-11-03-43-47.png)

# %% [markdown]
# ![](2024-08-11-03-44-09.png)

# %% [markdown]
# ![](2024-08-11-03-44-45.png)

# %% [markdown]
# ![](2024-08-11-03-45-17.png)

# %% [markdown]
# ![](2024-08-11-03-45-40.png)

# %% [markdown]
# > sometimes you are authenticated, but ...

# %% [markdown]
# ![](2024-08-11-03-46-03.png)

# %% [markdown]
# ![](2024-08-11-03-47-19.png)

# %% [markdown]
# ![](2024-08-11-03-48-09.png)

# %% [markdown]
# ![](2024-08-11-03-48-43.png)

# %% [markdown]
# #### **access-control**

# %% [markdown]
# ![](2024-08-11-03-53-29.png)

# %% [markdown]
# ![](2024-08-11-03-55-07.png)

# %% [markdown]
# ![](2024-08-11-04-02-19.png)

# %% [markdown]
# ![](2024-08-11-04-02-36.png)

# %% [markdown]
# ![](2024-08-11-04-02-53.png)

# %% [markdown]
# ![](2024-08-11-04-03-12.png)

# %% [markdown]
# ![](2024-08-11-04-04-04.png)

# %% [markdown]
# ![](2024-08-11-04-04-16.png)

# %% [markdown]
# ![](2024-08-11-04-05-21.png)

# %% [markdown]
# ### **writing your first api next steps**

# %% [markdown]
# #### **01_book-list-api-project**

# %% [markdown]
# ![](2024-08-11-04-09-31.png)

# %% [markdown]
# ![](2024-08-11-04-10-17.png)

# %% [markdown]
# ![](2024-08-11-04-11-02.png)

# %% [markdown]
# ![](2024-08-11-04-11-57.png)

# %% [markdown]
# ![](2024-08-11-04-12-28.png)

# %% [markdown]
# > One for browsing one book and another to brows all items.

# %% [markdown]
# ![](2024-08-11-04-20-17.png)

# %% [markdown]
# ![](2024-08-11-04-22-05.png)

# %% [markdown]
# ![](2024-08-11-04-22-21.png)

# %% [markdown]
# ![](2024-08-11-04-23-32.png)

# %% [markdown]
# ![](2024-08-11-04-26-54.png)

# %% [markdown]
# ![](2024-08-11-04-28-33.png)

# %% [markdown]
# ![](2024-08-11-04-34-28.png)

# %% [markdown]
# ![](2024-08-11-04-36-03.png)

# %% [markdown]
# ![](2024-08-11-04-40-46.png)

# %% [markdown]
# ![](2024-08-11-04-36-45.png)

# %% [markdown]
# ![](2024-08-11-04-38-45.png)

# %% [markdown]
# ![](2024-08-11-04-37-24.png)

# %% [markdown]
# #### **02_organizing-an-api-project**

# %% [markdown]
# ![](2024-08-11-04-46-47.png)

# %% [markdown]
# ![](2024-08-11-04-48-01.png)

# %% [markdown]
# ![](2024-08-11-04-48-23.png)

# %% [markdown]
# ![](2024-08-11-04-48-51.png)

# %% [markdown]
# ![](2024-08-11-04-49-53.png)

# %% [markdown]
# ![](2024-08-11-04-50-38.png)

# %% [markdown]
# ![](2024-08-11-04-51-39.png)

# %% [markdown]
# ![](2024-08-11-04-52-01.png)

# %% [markdown]
# ![](2024-08-11-04-52-13.png)

# %% [markdown]
# ![](2024-08-11-04-52-38.png)

# %% [markdown]
# **Note:** You do not need a requirements file with pipenv.

# %% [markdown]
# ![](2024-08-11-04-53-59.png)

# %% [markdown]
# ![](2024-08-11-04-54-27.png)

# %% [markdown]
# ![](2024-08-11-04-55-00.png)

# %% [markdown]
# ![](2024-08-11-04-55-33.png)

# %% [markdown]
# ![](2024-08-11-04-56-10.png)

# %% [markdown]
# #### **05_debugging-your-api**

# %% [markdown]
# ![](2024-08-11-04-58-06.png)

# %% [markdown]
# ![](2024-08-11-04-59-16.png)

# %% [markdown]
# ![](2024-08-11-04-59-33.png)

# %% [markdown]
# **Note:** Clicking on Start Debugging runs the server automatically.

# %% [markdown]
# ![](2024-08-11-05-01-46.png)

# %% [markdown]
# #### **06_browser-tools-and-extensions-for-api-development**

# %% [markdown]
# ![](2024-08-11-05-04-02.png)

# %% [markdown]
# ![](2024-08-11-05-04-41.png)

# %% [markdown]
# ![](2024-08-11-05-05-03.png)

# %% [markdown]
# ![](2024-08-11-05-06-59.png)
