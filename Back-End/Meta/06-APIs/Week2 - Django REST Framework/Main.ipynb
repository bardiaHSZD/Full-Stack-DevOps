# %% [markdown]
# ### **Introduction to Django rest framework**

# %% [markdown]
# #### **what is the django rest framework drf**

# %% [markdown]
# ![](2024-08-11-05-31-58.png)

# %% [markdown]
# ![](2024-08-11-05-32-37.png)

# %% [markdown]
# ![](2024-08-11-05-33-19.png)

# %% [markdown]
# This is called serilization.

# %% [markdown]
# ![](2024-08-11-05-34-11.png)

# %% [markdown]
# ![](2024-08-11-05-35-08.png)

# %% [markdown]
# ![](2024-08-11-05-36-12.png)

# %% [markdown]
# ![](2024-08-11-05-36-37.png)

# %% [markdown]
# ![](2024-08-11-05-37-03.png)

# %% [markdown]
# ![](2024-08-11-05-37-33.png)

# %% [markdown]
# #### **installing and setting up drf**

# %% [markdown]
# ![](2024-08-11-05-45-22.png)

# %% [markdown]
# ![](2024-08-11-05-47-37.png)

# %% [markdown]
# ![](2024-08-11-05-48-18.png)

# %% [markdown]
# ![](2024-08-11-05-52-30.png)

# %% [markdown]
# ![](2024-08-11-05-54-23.png)

# %% [markdown]
# ![](2024-08-11-06-07-35.png)

# %% [markdown]
# ![](2024-08-11-06-11-37.png)

# %% [markdown]
# >python manage.py runserver

# %% [markdown]
# ![](2024-08-11-06-28-34.png)

# %% [markdown]
# ![](2024-08-11-06-30-26.png)

# %% [markdown]
# ![](2024-08-11-06-39-50.png)

# %% [markdown]
# ![](2024-08-11-06-40-39.png)

# %% [markdown]
# ![](2024-08-11-06-40-58.png)

# %% [markdown]
# Similarly, you can add 'PUT' and 'DELETE' as needed.

# %% [markdown]
# #### **better api view with decorators**

# %% [markdown]
# ![](2024-08-11-06-45-30.png)

# %% [markdown]
# without decorators ...

# %% [markdown]
# ![](2024-08-11-06-47-08.png)

# %% [markdown]
# ![](2024-08-11-06-46-39.png)

# %% [markdown]
# > revert and add 'POST'...

# %% [markdown]
# ![](2024-08-11-07-10-37.png)

# %% [markdown]
# by clicking on the OPTIONS button ...

# %% [markdown]
# ![](2024-08-11-07-11-47.png)

# %% [markdown]
# it also allows for

# %% [markdown]
# ![](2024-08-11-07-13-10.png)

# %% [markdown]
# ![](2024-08-11-07-13-59.png)

# %% [markdown]
# #### **function and class based views**

# %% [markdown]
# ![](2024-08-11-07-14-56.png)

# %% [markdown]
# ![](2024-08-11-07-15-25.png)

# %% [markdown]
# Let's implement a class based view ...

# %% [markdown]
# ![](2024-08-11-07-17-01.png)

# %% [markdown]
# ![](2024-08-11-07-18-01.png)

# %% [markdown]
# ![](2024-08-11-07-18-50.png)

# %% [markdown]
# ![](2024-08-11-07-29-51.png)

# %% [markdown]
# ![](2024-08-11-07-30-23.png)

# %% [markdown]
# pk stands for primary key

# %% [markdown]
# ![](2024-08-11-07-39-39.png)

# %% [markdown]
# ![](2024-08-11-07-42-24.png)

# %% [markdown]
# ![](2024-08-11-07-49-17.png)

# %% [markdown]
# ![](2024-08-11-07-51-04.png)

# %% [markdown]
# #### **django debug toolbar**

# %% [markdown]
# ![](2024-08-11-07-53-30.png)

# %% [markdown]
# ![](2024-08-11-07-58-30.png)

# %% [markdown]
# ![](2024-08-11-07-59-01.png)

# %% [markdown]
# ![](2024-08-11-08-00-29.png)

# %% [markdown]
# ![](2024-08-11-08-01-49.png)

# %% [markdown]
# ![](2024-08-11-08-03-00.png)

# %% [markdown]
# ![](2024-08-11-08-04-57.png)

# %% [markdown]
# ![](2024-08-11-08-05-39.png)

# %% [markdown]
# ![](2024-08-11-08-06-14.png)

# %% [markdown]
# ![](2024-08-11-08-06-43.png)

# %% [markdown]
# #### **restaurant menu api project with drf**

# %% [markdown]
# ![](2024-08-11-08-16-38.png)

# %% [markdown]
# ![](2024-08-11-08-07-46.png)

# %% [markdown]
# ![](2024-08-11-08-18-47.png)

# %% [markdown]
# ![](2024-08-11-08-23-53.png)

# %% [markdown]
# ![](2024-08-11-08-29-46.png)

# %% [markdown]
# ![](2024-08-11-08-31-36.png)

# %% [markdown]
# ![](2024-08-11-08-52-27.png)

# %% [markdown]
# ![](2024-08-11-08-52-52.png)

# %% [markdown]
# ![](2024-08-11-08-53-07.png)

# %% [markdown]
# ![](2024-08-11-08-53-58.png)

# %% [markdown]
# ![](2024-08-11-08-54-17.png)

# %% [markdown]
# ![](2024-08-11-08-54-44.png)

# %% [markdown]
# ### **Django rest framework essentials**

# %% [markdown]
#  #### **serializers**

# %% [markdown]
# ![](2024-08-12-06-25-04.png)

# %% [markdown]
# ![](2024-08-12-06-26-03.png)

# %% [markdown]
# ![](2024-08-12-06-26-25.png)

# %% [markdown]
# ![](2024-08-12-06-26-48.png)

# %% [markdown]
# ![](2024-08-12-06-39-33.png)

# %% [markdown]
# ![](2024-08-12-06-41-07.png)

# %% [markdown]
# without the serilizer you cannot hide a piece of rendered data.

# %% [markdown]
# ![](2024-08-12-06-46-15.png)

# %% [markdown]
# ![](2024-08-12-06-48-16.png)

# %% [markdown]
# ![](2024-08-12-06-58-22.png)

# %% [markdown]
# ![](2024-08-12-07-15-44.png)

# %% [markdown]
# ![](2024-08-12-07-16-31.png)

# %% [markdown]
# ![](2024-08-12-07-20-25.png)

# %% [markdown]
# ![](2024-08-12-07-21-06.png)

# %% [markdown]
# ![](2024-08-12-07-21-20.png)

# %% [markdown]
# ![](2024-08-12-07-26-00.png)

# %% [markdown]
# ![](2024-08-12-07-26-25.png)

# %% [markdown]
# ![](2024-08-12-07-27-14.png)

# %% [markdown]
#  #### **model-serializers**

# %% [markdown]
# ![](2024-08-17-01-11-49.png)

# %% [markdown]
# ![](2024-08-17-01-14-20.png)

# %% [markdown]
# ![](2024-08-17-01-24-21.png)

# %% [markdown]
# ![](2024-08-17-01-30-19.png)

# %% [markdown]
#  #### **relationship-serializers**

# %% [markdown]
# ![](2024-08-17-01-31-33.png)

# %% [markdown]
# ![](2024-08-17-01-32-39.png)

# %% [markdown]
# **Note:** This way Category will not be deleted, unless all items in MenuItem are deleted.

# %% [markdown]
# ![](2024-08-17-02-26-28.png)

# %% [markdown]
# ![](2024-08-17-02-27-14.png)

# %% [markdown]
# ![](2024-08-17-02-29-09.png)

# %% [markdown]
# ![](2024-08-17-02-30-37.png)

# %% [markdown]
# ![](2024-08-17-02-32-03.png)

# %% [markdown]
# ![](2024-08-17-02-33-29.png)

# %% [markdown]
#  #### **deserialization-and-validation**

# %% [markdown]
# ![](2024-08-17-02-56-21.png)

# %% [markdown]
# ![](2024-08-17-02-57-13.png)

# %% [markdown]
# ![](2024-08-17-02-58-35.png)

# %% [markdown]
# Only after the Save() method is called, you can access the data:

# %% [markdown]
# ![](2024-08-17-02-59-38.png)

# %% [markdown]
# ![](2024-08-17-03-07-02.png)

# %% [markdown]
# ![](2024-08-17-03-10-02.png)

# %% [markdown]
# ![](2024-08-17-03-13-24.png)

# %% [markdown]
# ![](2024-08-17-03-13-42.png)

# %% [markdown]
# ![](2024-08-17-03-14-16.png)

# %% [markdown]
# ![](2024-08-17-03-15-38.png)

# %% [markdown]
# ![](2024-08-17-03-16-06.png)

# %% [markdown]
# ![](2024-08-17-03-16-53.png)

# %% [markdown]
# ![](2024-08-17-03-17-29.png)

# %% [markdown]
#  #### **renderers**

# %% [markdown]
# JSON, XML, YAML are most common renderers.

# %% [markdown]
# ![](2024-08-17-03-18-48.png)

# %% [markdown]
# ![](2024-08-17-03-19-12.png)

# %% [markdown]
# ![](2024-08-17-03-19-45.png)

# %% [markdown]
# ![](2024-08-17-03-21-00.png)

# %% [markdown]
# ![](2024-08-17-03-21-47.png)

# %% [markdown]
# ![](2024-08-17-03-23-20.png)

# %% [markdown]
# ![](2024-08-17-03-22-44.png)

# %% [markdown]
# ![](2024-08-17-03-23-38.png)

# %% [markdown]
# ![](2024-08-17-03-24-00.png)

# %% [markdown]
# ![](2024-08-17-03-24-31.png)

# %% [markdown]
# ![](2024-08-17-03-24-59.png)

# %% [markdown]
# ![](2024-08-17-03-25-19.png)

# %% [markdown]
# ![](2024-08-17-03-25-54.png)

# %% [markdown]
# ![](2024-08-17-03-26-07.png)

# %% [markdown]
# ![](2024-08-17-03-26-57.png)

# %% [markdown]
# ![](2024-08-17-03-27-16.png)

# %% [markdown]
# ![](2024-08-17-03-27-48.png)

# %% [markdown]
# ![](2024-08-17-03-28-13.png)
