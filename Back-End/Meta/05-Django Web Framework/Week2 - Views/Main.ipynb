# %% [markdown]
# ## **views**

# %% [markdown]
# ![](2024-07-31-23-21-48.png)

# %% [markdown]
# ![](2024-07-31-23-22-20.png)

# %% [markdown]
# ![](2024-07-31-23-23-03.png)

# %% [markdown]
# However, in Django we need to define it in a view:

# %% [markdown]
# ![](2024-07-31-23-25-37.png)

# %% [markdown]
# ![](2024-07-31-23-26-06.png)

# %% [markdown]
# ![](2024-07-31-23-26-41.png)

# %% [markdown]
# ![](2024-07-31-23-27-03.png)

# %% [markdown]
# ![](2024-07-31-23-27-39.png)

# %% [markdown]
# ![](2024-07-31-23-28-53.png)

# %% [markdown]
# ![](2024-07-31-23-30-09.png)

# %% [markdown]
# ![](2024-07-31-23-32-15.png)

# %% [markdown]
# ![](2024-07-31-23-32-42.png)

# %% [markdown]
# ![](2024-07-31-23-33-18.png)

# %% [markdown]
# ![](2024-07-31-23-35-08.png)

# %% [markdown]
# ![](2024-07-31-23-36-30.png)

# %% [markdown]
# ![](2024-07-31-23-39-06.png)

# %% [markdown]
# ![](2024-07-31-23-40-07.png)

# %% [markdown]
# ![](2024-07-31-23-41-21.png)

# %% [markdown]
# ![](2024-07-31-23-51-07.png)

# %% [markdown]
# ![](2024-07-31-23-54-42.png)

# %% [markdown]
# ![](2024-07-31-23-55-27.png)

# %% [markdown]
# ![](2024-07-31-23-56-34.png)

# %% [markdown]
# ![](2024-07-31-23-56-47.png)

# %% [markdown]
#  ![](2024-07-31-23-57-22.png)

# %% [markdown]
# ![](2024-07-31-23-58-35.png)

# %% [markdown]
# ![](2024-07-31-23-59-28.png)

# %% [markdown]
# ![](2024-08-01-00-00-17.png)

# %% [markdown]
# ![](2024-08-01-00-00-41.png)

# %% [markdown]
# ![](2024-08-01-00-01-14.png)

# %% [markdown]
#  ![](2024-08-01-00-02-21.png)

# %% [markdown]
# ![](2024-08-01-00-02-49.png)

# %% [markdown]
#  ![](2024-08-01-00-25-27.png)

# %% [markdown]
# ![](2024-08-01-00-25-57.png)

# %% [markdown]
# ![](2024-08-01-00-26-15.png)

# %% [markdown]
# ![](2024-08-01-00-32-52.png)

# %% [markdown]
# ![](2024-08-01-00-49-53.png)

# %% [markdown]
# ![](2024-08-01-00-50-37.png)

# %% [markdown]
# ![](2024-08-01-00-50-56.png)

# %% [markdown]
# ## **requests and urls**

# %% [markdown]
# ### **HTTP Requests/Responses**

# %% [markdown]
# ![](2024-08-01-01-16-18.png)

# %% [markdown]
# ![](2024-08-01-01-16-57.png)

# %% [markdown]
# ![](2024-08-01-01-17-30.png)

# %% [markdown]
# ![](2024-08-01-01-17-47.png)

# %% [markdown]
# ![](2024-08-01-01-41-43.png)

# %% [markdown]
# ![](2024-08-01-01-18-26.png)

# %% [markdown]
# ![](2024-08-01-01-20-04.png)

# %% [markdown]
# ![](2024-08-01-01-20-20.png)

# %% [markdown]
# ![](2024-08-01-01-26-35.png)

# %% [markdown]
# ![](2024-08-01-01-27-37.png)

# %% [markdown]
# ![](2024-08-01-01-28-29.png)

# %% [markdown]
# ![](2024-08-01-01-29-04.png)

# %% [markdown]
# ![](2024-08-01-01-29-35.png)

# %% [markdown]
# ![](2024-08-01-01-29-57.png)

# %% [markdown]
# ![](2024-08-01-01-30-20.png)

# %% [markdown]
# ![](2024-08-01-01-30-37.png)

# %% [markdown]
# ![](2024-08-01-01-31-06.png)

# %% [markdown]
# ![](2024-08-01-01-35-47.png)

# %% [markdown]
# ![](2024-08-01-01-36-09.png)

# %% [markdown]
# ![](2024-08-01-01-37-07.png)

# %% [markdown]
# ![](2024-08-01-01-31-47.png)

# %% [markdown]
# ![](2024-08-01-01-37-37.png)

# %% [markdown]
# ![](2024-08-01-01-38-41.png)

# %% [markdown]
# ![](2024-08-01-01-40-55.png)

# %% [markdown]
# ### **Creating HTTP Requests and Responses**

# %% [markdown]
# ![](2024-08-01-01-52-18.png)

# %% [markdown]
# ![](2024-08-01-01-52-55.png)

# %% [markdown]
# ![](2024-08-01-01-53-38.png)

# %% [markdown]
# ![](2024-08-01-01-54-08.png)

# %% [markdown]
# ![](2024-08-01-01-58-02.png)

# %% [markdown]
# ![](2024-08-01-01-59-00.png)

# %% [markdown]
# ![](2024-08-01-02-00-47.png)

# %% [markdown]
# ![](2024-08-01-02-01-39.png)

# %% [markdown]
# ![](2024-08-01-02-05-05.png)

# %% [markdown]
# ![](2024-08-01-02-02-13.png)

# %% [markdown]
# ![](2024-08-01-02-02-55.png)

# %% [markdown]
# ![](2024-08-01-02-03-16.png)

# %% [markdown]
# ![](2024-08-01-02-03-37.png)

# %% [markdown]
# ### **Understanding URLs**

# %% [markdown]
# ### **Mapping URLs with Params**

# %% [markdown]
# ## **creating urls and views**
