# %% [markdown]
# ## **models migrations**

# %% [markdown]
# ### **models**

# %% [markdown]
# ![](2024-08-01-12-26-14.png)

# %% [markdown]
# ![](2024-08-01-12-27-07.png)

# %% [markdown]
# ![](2024-08-01-12-28-24.png)

# %% [markdown]
# ![](2024-08-01-12-29-26.png)

# %% [markdown]
# ![](2024-08-01-12-29-54.png)

# %% [markdown]
# ![](2024-08-01-12-31-45.png)

# %% [markdown]
# ![](2024-08-01-12-32-00.png)

# %% [markdown]
# ![](2024-08-01-12-34-34.png)

# %% [markdown]
# ![](2024-08-01-12-35-36.png)

# %% [markdown]
# ![](2024-08-01-12-36-27.png)

# %% [markdown]
# ![](2024-08-01-12-36-41.png)

# %% [markdown]
# ![](2024-08-01-13-01-38.png)

# %% [markdown]
# ![](2024-08-01-13-02-02.png)

# %% [markdown]
# ![](2024-08-01-13-02-31.png)

# %% [markdown]
# ![](2024-08-01-13-03-09.png)

# %% [markdown]
# ![](2024-08-01-13-03-30.png)

# %% [markdown]
# ![](2024-08-01-13-04-17.png)

# %% [markdown]
# ### **creating models**

# %% [markdown]
# ![](2024-08-01-13-11-13.png)

# %% [markdown]
# ![](2024-08-01-13-11-36.png)

# %% [markdown]
# ![](2024-08-01-13-12-41.png)

# %% [markdown]
# ![](2024-08-01-13-13-03.png)

# %% [markdown]
# ![](2024-08-01-13-13-34.png)

# %% [markdown]
# ![](2024-08-01-13-14-17.png)

# %% [markdown]
# ![](2024-08-01-13-14-45.png)

# %% [markdown]
# ![](2024-08-01-13-21-31.png)

# %% [markdown]
# ![](2024-08-01-13-21-57.png)

# %% [markdown]
# ![](2024-08-01-13-22-14.png)

# %% [markdown]
# ![](2024-08-01-13-22-35.png)

# %% [markdown]
# ![](2024-08-01-13-23-09.png)

# %% [markdown]
# ![](2024-08-01-13-23-36.png)

# %% [markdown]
# ![](2024-08-01-13-23-56.png)

# %% [markdown]
# ![](2024-08-01-13-24-20.png)

# %% [markdown]
# Enter the shell again ...

# %% [markdown]
# ![](2024-08-01-13-25-00.png)

# %% [markdown]
# ![](2024-08-01-13-25-17.png)

# %% [markdown]
# ![](2024-08-01-13-27-46.png)

# %% [markdown]
# ### **migrations**

# %% [markdown]
# ![](2024-08-01-23-45-40.png)

# %% [markdown]
# ![](2024-08-01-23-46-15.png)

# %% [markdown]
# ![](2024-08-01-23-47-09.png)

# %% [markdown]
# ![](2024-08-01-23-47-52.png)

# %% [markdown]
# ![](2024-08-01-23-48-17.png)

# %% [markdown]
# ![](2024-08-01-23-50-19.png)

# %% [markdown]
# ![](2024-08-01-23-51-58.png)

# %% [markdown]
# ![](2024-08-01-23-52-26.png)

# %% [markdown]
# ![](2024-08-01-23-53-55.png)

# %% [markdown]
# ![](2024-08-01-23-54-27.png)

# %% [markdown]
# ### **working with migrations**

# %% [markdown]
# ![](2024-08-01-23-59-28.png)

# %% [markdown]
# ![](2024-08-02-00-03-02.png)

# %% [markdown]
# ![](2024-08-02-00-05-10.png)

# %% [markdown]
# ![](2024-08-02-00-07-06.png)

# %% [markdown]
# ![](2024-08-02-00-10-30.png)

# %% [markdown]
# ![](2024-08-02-00-11-26.png)

# %% [markdown]
# ![](2024-08-02-00-12-04.png)

# %% [markdown]
# Reverting back to a previous model ...

# %% [markdown]
# ![](2024-08-02-00-13-25.png)

# %% [markdown]
# ![](2024-08-02-00-19-59.png)

# %% [markdown]
# ### **a history of changes**

# %% [markdown]
# ![](2024-08-02-00-35-09.png)

# %% [markdown]
# ![](2024-08-02-00-35-39.png)

# %% [markdown]
# ![](2024-08-02-00-36-13.png)

# %% [markdown]
# ![](2024-08-02-00-37-15.png)

# %% [markdown]
# ![](2024-08-02-00-37-39.png)

# %% [markdown]
# ![](2024-08-02-00-37-58.png)

# %% [markdown]
# ![](2024-08-02-00-38-21.png)

# %% [markdown]
# ![](2024-08-02-00-38-44.png)

# %% [markdown]
# ![](2024-08-02-00-39-32.png)

# %% [markdown]
# ![](2024-08-02-00-39-57.png)

# %% [markdown]
# ### **models using foreign keys**

# %% [markdown]
# ![](2024-08-02-00-40-29.png)

# %% [markdown]
# ![](2024-08-02-00-44-43.png)

# %% [markdown]
# ![](2024-08-02-00-44-27.png)

# %% [markdown]
# ![](2024-08-02-00-52-30.png)

# %% [markdown]
# ![](2024-08-02-00-52-56.png)

# %% [markdown]
# ![](2024-08-02-00-54-42.png)

# %% [markdown]
# ![](2024-08-02-00-55-02.png)

# %% [markdown]
# ![](2024-08-02-00-55-39.png)

# %% [markdown]
# ![](2024-08-02-00-56-03.png)

# %% [markdown]
#   ![](2024-08-02-00-56-40.png)

# %% [markdown]
# ![](2024-08-02-00-57-20.png)

# %% [markdown]
# ![](2024-08-02-00-57-56.png)

# %% [markdown]
# ![](2024-08-02-00-58-43.png)

# %% [markdown]
# Assume two items are added ... now open the database again.

# %% [markdown]
# ![](2024-08-02-01-05-19.png)

# %% [markdown]
# ![](2024-08-02-01-06-41.png)

# %% [markdown]
#  ![](2024-08-02-01-08-26.png)

# %% [markdown]
#  ![](2024-08-02-01-09-03.png)

# %% [markdown]
# with on_delete=models.PROTECT no item will be deleted from the category menu, if a manu item is deleted and there is no reference to category menu.

# %% [markdown]
# ### **using orm**

# %% [markdown]
# ![](2024-08-02-01-18-18.png)

# %% [markdown]
# ![](2024-08-02-01-19-02.png)

# %% [markdown]
# ![](2024-08-02-01-21-08.png)

# %% [markdown]
# ![](2024-08-02-01-21-55.png)

# %% [markdown]
# ![](2024-08-02-01-22-45.png)

# %% [markdown]
# ![](2024-08-02-01-23-19.png)

# %% [markdown]
# ![](2024-08-02-01-26-45.png)

# %% [markdown]
# ![](2024-08-02-01-27-16.png)

# %% [markdown]
# ![](2024-08-02-01-28-14.png)

# %% [markdown]
# ![](2024-08-02-01-28-48.png)

# %% [markdown]
# ## **models and forms**

# %% [markdown]
#  ### **forms**

# %% [markdown]
#  ### **working with django form fields and data types**

# %% [markdown]
#  ### **creating forms**

# %% [markdown]
#  ### **model form**

# %% [markdown]
# ## **admin**

# %% [markdown]
#  ### **django admin**

# %% [markdown]
#  ### **adding groups and users**

# %% [markdown]
#  ### **permissions**

# %% [markdown]
#  ### **users and permissions**

# %% [markdown]
# ## **database configuration**

# %% [markdown]
# ### **database options**

# %% [markdown]
# ![](2024-08-02-01-36-54.png)

# %% [markdown]
# ![](2024-08-02-01-36-30.png)

# %% [markdown]
# ![](2024-08-02-01-41-57.png)

# %% [markdown]
# ![](2024-08-02-01-42-16.png)

# %% [markdown]
# ![](2024-08-02-01-42-55.png)

# %% [markdown]
# ![](2024-08-02-01-43-33.png)

# %% [markdown]
# ![](2024-08-02-01-44-10.png)

# %% [markdown]
# ![](2024-08-02-01-45-18.png)

# %% [markdown]
# ### **setting up a mysql connection**

# %% [markdown]
# MySQL is ...

# %% [markdown]
# ![](2024-08-02-01-46-58.png)

# %% [markdown]
# ![](2024-08-02-01-47-47.png)

# %% [markdown]
# ![](2024-08-02-01-48-22.png)

# %% [markdown]
# enter the password ...

# %% [markdown]
# ![](2024-08-02-01-48-54.png)

# %% [markdown]
# ![](2024-08-02-01-49-11.png)

# %% [markdown]
# ![](2024-08-02-01-49-46.png)

# %% [markdown]
# ![](2024-08-02-01-50-09.png)

# %% [markdown]
# ![](2024-08-02-01-50-34.png)

# %% [markdown]
# ![](2024-08-02-01-50-53.png)

# %% [markdown]
# ![](2024-08-02-01-51-23.png)

# %% [markdown]
# ![](2024-08-02-01-51-44.png)

# %% [markdown]
# ![](2024-08-02-01-52-04.png)

# %% [markdown]
# ![](2024-08-02-01-52-23.png)

# %% [markdown]
# ![](2024-08-02-01-52-46.png)

# %% [markdown]
# ![](2024-08-02-01-53-08.png)

# %% [markdown]
# ![](2024-08-02-01-53-41.png)
