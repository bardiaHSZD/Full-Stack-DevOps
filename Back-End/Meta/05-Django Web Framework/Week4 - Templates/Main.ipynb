# %% [markdown]
#  ## **templates**

# %% [markdown]
# ### **templates**

# %% [markdown]
# ![](2024-08-18-05-20-10.png)

# %% [markdown]
# ![](2024-08-18-05-20-39.png)

# %% [markdown]
# ![](2024-08-18-05-20-53.png)

# %% [markdown]
# ![](2024-08-18-05-21-19.png)

# %% [markdown]
# ![](2024-08-18-05-21-42.png)

# %% [markdown]
# There are two types of content: static, and template.

# %% [markdown]
# ![](2024-08-18-05-25-24.png)

# %% [markdown]
# ![](2024-08-18-05-26-20.png)

# %% [markdown]
# ![](2024-08-18-05-26-57.png)

# %% [markdown]
# ![](2024-08-18-05-27-40.png)

# %% [markdown]
# ![](2024-08-18-05-28-00.png)

# %% [markdown]
# ![](2024-08-18-05-28-36.png)

# %% [markdown]
# ![](2024-08-18-05-29-10.png)

# %% [markdown]
# ![](2024-08-18-05-29-39.png)

# %% [markdown]
# ![](2024-08-18-05-31-00.png)

# %% [markdown]
# ![](2024-08-18-05-32-29.png)

# %% [markdown]
# ![](2024-08-18-05-35-05.png)

# %% [markdown]
# ![](2024-08-18-05-36-52.png)

# %% [markdown]
# ![](2024-08-18-05-37-26.png)

# %% [markdown]
# ![](2024-08-18-05-37-46.png)

# %% [markdown]
# ![](2024-08-18-05-38-29.png)

# %% [markdown]
# ![](2024-08-18-05-38-50.png)

# %% [markdown]
# ![](2024-08-18-05-48-52.png)

# %% [markdown]
# ![](2024-08-18-05-49-20.png)

# %% [markdown]
# ### **creating templates**

# %% [markdown]
# ![](2024-08-18-05-52-37.png)

# %% [markdown]
# ![](2024-08-18-05-53-19.png)

# %% [markdown]
# The render function takes three parameters:

# %% [markdown]
# ![](2024-08-18-05-54-23.png)

# %% [markdown]
# ![](2024-08-18-05-54-52.png)

# %% [markdown]
# ![](2024-08-18-05-55-10.png)

# %% [markdown]
# ![](2024-08-18-05-56-43.png)

# %% [markdown]
# ![](2024-08-18-05-57-36.png)

# %% [markdown]
# Define a view that returns the render function ...

# %% [markdown]
# ![](2024-08-18-05-58-27.png)

# %% [markdown]
# ![](2024-08-18-05-59-01.png)

# %% [markdown]
# ![](2024-08-18-06-01-06.png)

# %% [markdown]
#  ![](2024-08-18-06-01-39.png)

# %% [markdown]
# ![](2024-08-18-06-02-15.png)

# %% [markdown]
# ![](2024-08-18-06-06-10.png)

# %% [markdown]
# ![](2024-08-18-06-06-37.png)

# %% [markdown]
# ![](2024-08-18-06-07-26.png)

# %% [markdown]
# ![](2024-08-18-06-09-44.png)

# %% [markdown]
# ![](2024-08-18-06-10-21.png)

# %% [markdown]
# ![](2024-08-18-06-11-17.png)

# %% [markdown]
# By typing an "!" and clicking on the first option, it will generate the basic html:

# %% [markdown]
# ![](2024-08-18-06-13-11.png)

# %% [markdown]
# ![](2024-08-18-06-14-44.png)

# %% [markdown]
# ![](2024-08-18-06-15-55.png)

# %% [markdown]
# ![](2024-08-18-06-16-36.png)

# %% [markdown]
# ![](2024-08-18-06-17-14.png)

# %% [markdown]
# ![](2024-08-18-06-18-06.png)

# %% [markdown]
# ![](2024-08-18-06-18-40.png)

# %% [markdown]
# ![](2024-08-18-06-20-56.png)

# %% [markdown]
# ![](2024-08-18-06-21-20.png)

# %% [markdown]
# ![](2024-08-18-06-21-56.png)

# %% [markdown]
# ![](2024-08-18-06-22-13.png)

# %% [markdown]
#  ## **working with templates**

# %% [markdown]
# ### **working with template language**

# %% [markdown]
# ### **dynamic templates in django**

# %% [markdown]
# ### **mapping model objects to a template**

# %% [markdown]
# ### **template inheritance**

# %% [markdown]
# ### **working with template inheritance**

# %% [markdown]
#  ## **debugging and testing**

# %% [markdown]
# ### **debugging django applications**

# %% [markdown]
# ![](2024-08-18-06-32-52.png)

# %% [markdown]
# ![](2024-08-18-06-33-33.png)

# %% [markdown]
#  ![](2024-08-18-06-34-19.png)

# %% [markdown]
# ![](2024-08-18-06-37-29.png)

# %% [markdown]
# ![](2024-08-18-06-38-06.png)

# %% [markdown]
# ![](2024-08-18-06-38-29.png)

# %% [markdown]
# ![](2024-08-18-06-39-00.png)

# %% [markdown]
# ### **testing in django**

# %% [markdown]
# ![](2024-08-18-06-40-04.png)

# %% [markdown]
# ![](2024-08-18-06-40-30.png)

# %% [markdown]
# ![](2024-08-18-06-50-06.png)

# %% [markdown]
# ![](2024-08-18-06-50-30.png)

# %% [markdown]
# ![](2024-08-18-06-52-11.png)

# %% [markdown]
# ![](2024-08-18-06-56-04.png)

# %% [markdown]
# ![](2024-08-18-06-56-53.png)

# %% [markdown]
# ![](2024-08-18-06-57-12.png)

# %% [markdown]
# ![](2024-08-18-06-57-39.png)

# %% [markdown]
# ![](2024-08-18-06-58-14.png)

# %% [markdown]
# ![](2024-08-18-06-59-17.png)

# %% [markdown]
# ![](2024-08-18-07-00-23.png)

# %% [markdown]
# ![](2024-08-18-07-02-25.png)

# %% [markdown]
# ![](2024-08-18-07-02-56.png)

# %% [markdown]
# ![](2024-08-18-07-03-27.png)

# %% [markdown]
# ![](2024-08-18-07-04-39.png)

# %% [markdown]
# ![](2024-08-18-07-04-56.png)

# %% [markdown]
# ![](2024-08-18-07-05-24.png)

# %% [markdown]
# ![](2024-08-18-07-05-48.png)
