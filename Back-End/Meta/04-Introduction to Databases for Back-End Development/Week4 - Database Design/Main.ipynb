# %% [markdown]
# ## **Designing Database Schema**

# %% [markdown]
# ### **Database Schema**

# %% [markdown]
# ### **Schema in Use**

# %% [markdown]
# ### **Databse Schema in Use**

# %% [markdown]
# ## **Relational Database Design**

# %% [markdown]
# ### **Table Relationships**

# %% [markdown]
# ### **Primary Key**

# %% [markdown]
# ### **Foreign Key**

# %% [markdown]
# ### **Finding Entities**

# %% [markdown]
# ## **Database Normalization**

# %% [markdown]
# ### **What is Database Normalization**

# %% [markdown]
# ### **First Normal Form 1nf**

# %% [markdown]
# ### **Second Normal Form 2nf**

# %% [markdown]
# ### **Third Normal Form 3nf**
