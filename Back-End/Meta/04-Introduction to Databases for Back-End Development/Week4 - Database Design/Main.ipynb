# %% [markdown]
# ## **Designing Database Schema**

# %% [markdown]
# ### **Database Schema**

# %% [markdown]
# ![](2024-07-27-12-56-32.png)

# %% [markdown]
# ![](2024-07-27-12-57-00.png)

# %% [markdown]
# ![](2024-07-27-12-57-26.png)

# %% [markdown]
# ![](2024-07-27-12-58-05.png)

# %% [markdown]
# ### **Schema in Use**

# %% [markdown]
# ![](2024-07-27-12-59-08.png)

# %% [markdown]
# ![](2024-07-27-13-00-16.png)

# %% [markdown]
# ![](2024-07-27-13-01-19.png)

# %% [markdown]
# ### **Types of Databse Schemas**

# %% [markdown]
# ![](2024-07-27-13-03-05.png)

# %% [markdown]
# ## **Relational Database Design**

# %% [markdown]
# ### **Table Relationships**

# %% [markdown]
# ![](2024-07-27-13-05-07.png)

# %% [markdown]
# ![](2024-07-27-13-05-43.png)

# %% [markdown]
# ![](2024-07-27-13-06-14.png)

# %% [markdown]
# ![](2024-07-27-13-06-47.png)

# %% [markdown]
# ![](2024-07-27-13-07-22.png)

# %% [markdown]
# ### **Primary Key**

# %% [markdown]
# ![](2024-07-27-13-08-25.png)

# %% [markdown]
# ![](2024-07-27-13-08-51.png)

# %% [markdown]
# ![](2024-07-27-13-09-39.png)

# %% [markdown]
# ### **Foreign Key**

# %% [markdown]
# ![](2024-07-27-13-10-37.png)

# %% [markdown]
# ![](2024-07-27-13-11-49.png)

# %% [markdown]
# ![](2024-07-27-13-12-41.png)

# %% [markdown]
# ![](2024-07-27-13-12-58.png)

# %% [markdown]
# ### **Finding Entities**

# %% [markdown]
# ![](2024-07-27-13-13-57.png)

# %% [markdown]
# ![](2024-07-27-13-14-15.png)

# %% [markdown]
# ![](2024-07-27-13-14-51.png)

# %% [markdown]
# ## **Database Normalization**

# %% [markdown]
# ### **What is Database Normalization**

# %% [markdown]
# ![](2024-07-28-00-40-36.png)

# %% [markdown]
# ![](2024-07-28-00-41-12.png)

# %% [markdown]
# ![](2024-07-28-00-41-46.png)

# %% [markdown]
# ![](2024-07-28-00-42-40.png)

# %% [markdown]
# ![](2024-07-28-00-43-00.png)

# %% [markdown]
# ![](2024-07-28-00-43-26.png)

# %% [markdown]
# ![](2024-07-28-00-43-59.png)

# %% [markdown]
# ![](2024-07-28-00-44-27.png)

# %% [markdown]
# ![](2024-07-28-00-44-53.png)

# %% [markdown]
# ![](2024-07-28-00-45-20.png)

# %% [markdown]
# ![](2024-07-28-00-46-10.png)

# %% [markdown]
# ![](2024-07-28-00-46-39.png)

# %% [markdown]
# ![](2024-07-28-00-47-13.png)

# %% [markdown]
# ### **First Normal Form 1nf**

# %% [markdown]
# ![](2024-07-28-00-49-38.png)

# %% [markdown]
# ![](2024-07-28-00-51-23.png)

# %% [markdown]
# ![](2024-07-28-00-52-01.png)

# %% [markdown]
# ![](2024-07-28-00-52-19.png)

# %% [markdown]
# ![](2024-07-28-00-52-49.png)

# %% [markdown]
# ![](2024-07-28-00-53-16.png)

# %% [markdown]
# ![](2024-07-28-00-53-46.png)

# %% [markdown]
# ![](2024-07-28-00-54-12.png)

# %% [markdown]
# ![](2024-07-28-00-54-35.png)

# %% [markdown]
# ![](2024-07-28-00-55-24.png)

# %% [markdown]
# ![](2024-07-28-00-57-35.png)

# %% [markdown]
# ### **Second Normal Form 2nf**

# %% [markdown]
# ![](2024-07-28-00-58-42.png)

# %% [markdown]
# ![](2024-07-28-00-59-12.png)

# %% [markdown]
# ![](2024-07-28-00-59-24.png)

# %% [markdown]
# ![](2024-07-28-01-00-28.png)

# %% [markdown]
# ![](2024-07-28-01-00-48.png)

# %% [markdown]
# ![](2024-07-28-01-01-08.png)

# %% [markdown]
# ![](2024-07-28-01-01-48.png)

# %% [markdown]
# ![](2024-07-28-01-02-17.png)

# %% [markdown]
# ![](2024-07-28-01-04-48.png)

# %% [markdown]
# ![](2024-07-28-01-05-20.png)

# %% [markdown]
# ![](2024-07-28-01-06-19.png)

# %% [markdown]
# ### **Third Normal Form 3nf**

# %% [markdown]
# **Note:** The database must be in 1NF and 2NF before it can be in 3NF.

# %% [markdown]
# ![](2024-07-28-01-09-26.png)

# %% [markdown]
# ![](2024-07-28-01-12-57.png)

# %% [markdown]
# ![](2024-07-28-01-13-41.png)

# %% [markdown]
# ![](2024-07-28-01-14-57.png)

# %% [markdown]
# ![](2024-07-28-01-15-22.png)

# %% [markdown]
# ![](2024-07-28-01-15-55.png)

# %% [markdown]
# ![](2024-07-28-01-16-28.png)
