# %% [markdown]
# ## **SQL Arithmatic Operators**

# %% [markdown]
# ![](2024-07-27-03-51-18.png)

# %% [markdown]
# ![](2024-07-27-03-52-29.png)

# %% [markdown]
# ![](2024-07-27-03-52-57.png)

# %% [markdown]
# ![](2024-07-27-03-53-24.png)

# %% [markdown]
# ![](2024-07-27-03-53-48.png)

# %% [markdown]
# ![](2024-07-27-03-54-38.png)

# %% [markdown]
# ![](2024-07-27-03-55-07.png)

# %% [markdown]
# ![](2024-07-27-03-56-19.png)

# %% [markdown]
# ## **Operators in Use**

# %% [markdown]
# ![](2024-07-27-03-57-12.png)

# %% [markdown]
# ![](2024-07-27-03-57-52.png)

# %% [markdown]
# ![](2024-07-27-03-59-14.png)

# %% [markdown]
# ## **SQL Comparison Operators**

# %% [markdown]
# ![](2024-07-27-04-15-18.png)

# %% [markdown]
# ![](2024-07-27-04-16-55.png)

# %% [markdown]
# ![](2024-07-27-04-17-33.png)

# %% [markdown]
# ![](2024-07-27-04-18-33.png)

# %% [markdown]
# ![](2024-07-27-04-21-57.png)

# %% [markdown]
# ![](2024-07-27-04-22-53.png)

# %% [markdown]
# ![](2024-07-27-04-24-01.png)

# %% [markdown]
# ![](2024-07-27-04-24-32.png)
