# %% [markdown]
# ## **Git and GitHub**

# %% [markdown]
# ### **What is Git and GitHub?**

# %% [markdown]
# ![](2024-07-26-07-03-06.png)

# %% [markdown]
# ### **Creating and Cloning A Directory**

# %% [markdown]
# ![](2024-07-26-07-10-19.png)

# %% [markdown]
# ![](2024-07-26-07-14-15.png)

# %% [markdown]
# ![](2024-07-26-07-17-46.png)

# %% [markdown]
# ![](2024-07-26-07-19-44.png)

# %% [markdown]
# ### **How Git Works**

# %% [markdown]
# ![](2024-07-26-07-20-55.png)

# %% [markdown]
# ![](2024-07-26-07-27-25.png)

# %% [markdown]
# ![](2024-07-26-07-31-20.png)

# %% [markdown]
# ![](2024-07-26-07-32-52.png)

# %% [markdown]
# ### **Add and Commit**

# %% [markdown]
# ![](2024-07-26-07-34-59.png)

# %% [markdown]
# ![](2024-07-26-07-40-12.png)

# %% [markdown]
# ![](2024-07-26-07-41-57.png)

# %% [markdown]
# ![](2024-07-26-07-47-53.png)

# %% [markdown]
# ![](2024-07-26-07-51-04.png)

# %% [markdown]
# ![](2024-07-26-07-53-17.png)

# %% [markdown]
# ### **Branches**

# %% [markdown]
# ![](2024-07-26-07-57-18.png)

# %% [markdown]
# ![](2024-07-26-08-02-20.png)

# %% [markdown]
# ![](2024-07-26-08-07-02.png)

# %% [markdown]
# ![](2024-07-26-08-11-58.png)

# %% [markdown]
# ![](2024-07-26-08-13-06.png)

# %% [markdown]
# ![](2024-07-26-08-14-51.png)

# %% [markdown]
# ![](2024-07-26-08-15-23.png)

# %% [markdown]
# ![](2024-07-26-08-16-31.png)

# %% [markdown]
# ### **Remote vs Local**

# %% [markdown]
# ![](2024-07-26-08-25-54.png)

# %% [markdown]
# ![](2024-07-26-08-26-27.png)

# %% [markdown]
# ![](2024-07-26-08-27-51.png)

# %% [markdown]
# ![](2024-07-26-08-28-59.png)

# %% [markdown]
# ### **Push and Pull**

# %% [markdown]
# ![](2024-07-26-08-31-54.png)

# %% [markdown]
# ### **Example Workflow**

# %% [markdown]
# ![](2024-07-26-08-35-03.png)

# %% [markdown]
#  ![](2024-07-26-08-35-35.png)

# %% [markdown]
# ![](2024-07-26-08-39-01.png)

# %% [markdown]
# ![](2024-07-26-08-39-30.png)

# %% [markdown]
# ![](2024-07-26-08-42-23.png)

# %% [markdown]
# ![](2024-07-26-08-43-33.png)

# %% [markdown]
# ### **Head**

# %% [markdown]
# ![](2024-07-26-08-48-06.png)

# %% [markdown]
# ![](2024-07-26-08-48-49.png)

# %% [markdown]
# ![](2024-07-26-08-49-19.png)

# %% [markdown]
# ![](2024-07-26-08-49-46.png)

# %% [markdown]
# ![](2024-07-26-08-50-24.png)

# %% [markdown]
#  ![](2024-07-26-08-51-44.png)

# %% [markdown]
# ![](2024-07-26-08-53-00.png)

# %% [markdown]
# ![](2024-07-26-08-53-25.png)

# %% [markdown]
# ![](2024-07-26-08-53-42.png)

# %% [markdown]
# ![](2024-07-26-08-54-53.png)

# %% [markdown]
# ![](2024-07-26-08-55-33.png)

# %% [markdown]
# ### **Diff Commands**

# %% [markdown]
# ![](2024-07-26-08-56-23.png)

# %% [markdown]
# ![](2024-07-26-08-57-08.png)

# %% [markdown]
# ![](2024-07-26-09-09-26.png)

# %% [markdown]
# ![](2024-07-26-09-10-35.png)

# %% [markdown]
# ![](2024-07-26-09-12-50.png)

# %% [markdown]
# ![](2024-07-26-09-13-42.png)

# %% [markdown]
# ### **Blame**

# %% [markdown]
# ![](2024-07-26-09-14-40.png)

# %% [markdown]
# ![](2024-07-26-09-15-17.png)

# %% [markdown]
# ![](2024-07-26-09-16-01.png)

# %% [markdown]
# ![](2024-07-26-09-16-56.png)

# %% [markdown]
# ![](2024-07-26-09-17-36.png)

# %% [markdown]
# ![](2024-07-26-09-19-06.png)

# %% [markdown]
# ![](2024-07-26-09-20-02.png)

# %% [markdown]
# ![](2024-07-26-09-21-50.png)

# %% [markdown]
# ![](2024-07-26-09-22-21.png)
