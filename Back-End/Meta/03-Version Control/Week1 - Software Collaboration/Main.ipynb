# %% [markdown]
# ## **Course Introduction**

# %% [markdown]
# ![](2024-07-26-01-47-25.png)

# %% [markdown]
# ![](2024-07-26-01-47-51.png)

# %% [markdown]
# ![](2024-07-26-01-55-33.png)

# %% [markdown]
# ![](2024-07-26-01-57-12.png)

# %% [markdown]
# ![](2024-07-26-01-58-00.png)

# %% [markdown]
# ![](2024-07-26-01-58-44.png)

# %% [markdown]
# ![](2024-07-26-02-01-00.png)

# %% [markdown]
# ![](2024-07-26-02-01-20.png)

# %% [markdown]
# ![](2024-07-26-02-04-22.png)

# %% [markdown]
# ![](2024-07-26-02-04-46.png)

# %% [markdown]
# **Centralized**

# %% [markdown]
# ![](2024-07-26-02-05-15.png)

# %% [markdown]
# **Distributed**

# %% [markdown]
# ![](2024-07-26-02-06-35.png)
