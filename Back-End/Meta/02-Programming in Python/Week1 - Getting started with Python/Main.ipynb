# %% [markdown]
# ## **Course Introduction**

# %% [markdown]
# ![](2024-07-29-00-01-26.png)

# %% [markdown]
# ## **Welcome to Python Programming**

# %% [markdown]
# ### **introduction to programming**

# %% [markdown]
# ![](2024-07-29-00-17-42.png)

# %% [markdown]
# ### **python syntax spaces matter**

# %% [markdown]
# ![](2024-07-29-00-26-09.png)

# %% [markdown]
# ![](2024-07-29-00-26-57.png)

# %% [markdown]
# ### **variables**

# %% [markdown]
# ![](2024-07-29-00-30-15.png)

# %% [markdown]
# ### **basic data types**

# %% [markdown]
# ![](2024-07-29-00-32-07.png)

# %% [markdown]
# ![](2024-07-29-00-33-32.png)

# %% [markdown]
# ![](2024-07-29-00-35-05.png)

# %% [markdown]
# ### **strings**

# %% [markdown]
# ![](2024-07-29-00-37-55.png)

# %% [markdown]
# ### **type casting**

# %% [markdown]
# ![](2024-07-29-00-41-22.png)

# %% [markdown]
# ![](2024-07-29-00-42-03.png)

# %% [markdown]
# ![](2024-07-29-00-42-35.png)

# %% [markdown]
# ![](2024-07-29-00-43-31.png)

# %% [markdown]
# ![](2024-07-29-00-43-48.png)

# %% [markdown]
# ![](2024-07-29-00-44-12.png)

# %% [markdown]
# ![](2024-07-29-00-44-36.png)

# %% [markdown]
# ### **user input console output**

# %% [markdown]
# ![](2024-07-29-00-46-23.png)

# %% [markdown]
# ![](2024-07-29-00-47-15.png)

# %% [markdown]
# ![](2024-07-29-00-48-35.png)

# %% [markdown]
# ![](2024-07-29-00-51-01.png)

# %% [markdown]
# ## **Control Flow and Conditionals**

# %% [markdown]
#  ### **looping constructs**

# %% [markdown]
# ![](2024-07-29-01-35-15.png)

# %% [markdown]
# ![](2024-07-29-01-35-48.png)

# %% [markdown]
#  ### **nested loops and the effect on algorithmic complexity**

# %% [markdown]
# ![](2024-07-29-01-40-25.png)

# %% [markdown]
#  ### **switch statement**

# %% [markdown]
# ![](2024-07-29-01-27-23.png)

# %% [markdown]
# ![](2024-07-29-01-27-54.png)
