# %% [markdown]
# ## **Functions and Data Structures**

# %% [markdown]
# ### **Tuples**

# %% [markdown]
# ![](2024-07-30-00-05-34.png)

# %% [markdown]
# ![](2024-07-30-00-06-36.png)

# %% [markdown]
# ### **Sets**

# %% [markdown]
# ![](2024-07-30-00-11-14.png)

# %% [markdown]
# ![](2024-07-30-00-11-43.png)

# %% [markdown]
# ![](2024-07-30-00-12-04.png)

# %% [markdown]
# ![](2024-07-30-00-12-30.png)

# %% [markdown]
# ![](2024-07-30-00-13-21.png)

# %% [markdown]
# ![](2024-07-30-00-13-44.png)

# %% [markdown]
# ![](2024-07-30-00-14-42.png)

# %% [markdown]
# ![](2024-07-30-00-15-01.png)

# %% [markdown]
# ![](2024-07-30-00-15-41.png)

# %% [markdown]
# ### **Dictionary**

# %% [markdown]
# ![](2024-07-30-00-43-19.png)

# %% [markdown]
# ![](2024-07-30-00-44-15.png)

# %% [markdown]
# ### **Args and Kwargs**

# %% [markdown]
# ![](2024-07-30-00-46-38.png)

# %% [markdown]
# ![](2024-07-30-00-47-34.png)

# %% [markdown]
# ## **Exception Handeling and File Handling**

# %% [markdown]
# ![](2024-07-30-01-04-22.png)

# %% [markdown]
# ![](2024-07-30-01-07-16.png)

# %% [markdown]
# ![](2024-07-30-01-07-37.png)

# %% [markdown]
# ![](2024-07-30-01-10-51.png)

# %% [markdown]
# ![](2024-07-30-01-12-08.png)

# %% [markdown]
# ![](2024-07-30-01-12-55.png)
