# %% [markdown]
# ## **Modules**

# %% [markdown]
# ### **what is a module in python**

# %% [markdown]
# ![](2024-07-30-22-12-09.png)

# %% [markdown]
# ![](2024-07-30-22-12-45.png)

# %% [markdown]
# ### **accessing modules**

# %% [markdown]
# ![](2024-07-30-22-17-39.png)

# %% [markdown]
# ![](2024-07-30-22-30-35.png)

# %% [markdown]
# ### **the import statement**

# %% [markdown]
# ![](2024-07-30-22-53-55.png)

# %% [markdown]
# ![](2024-07-30-22-46-31.png)

# %% [markdown]
# ### **namespacing and scoping**

# %% [markdown]
# ![](2024-07-30-23-01-55.png)

# %% [markdown]
# ![](2024-07-30-23-02-27.png)

# %% [markdown]
# ### **reload function**

# %% [markdown]
# ![](2024-07-30-23-08-38.png)

# %% [markdown]
# ![](2024-07-30-23-09-09.png)

# %% [markdown]
# ![](2024-07-30-23-10-25.png)

# %% [markdown]
# ![](2024-07-30-23-12-05.png)

# %% [markdown]
# ![](2024-07-30-23-17-24.png)

# %% [markdown]
# ![](2024-07-30-23-20-15.png)

# %% [markdown]
#  ![](2024-07-30-23-20-45.png)

# %% [markdown]
# ![](2024-07-30-23-29-00.png)

# %% [markdown]
# ![](2024-07-30-23-30-05.png)

# %% [markdown]
# ![](2024-07-30-23-30-45.png)

# %% [markdown]
# Hit Enter again

# %% [markdown]
# ![](2024-07-30-23-31-20.png)

# %% [markdown]
# ## **Popular Packages and Frameworks**

# %% [markdown]
#  ### **popular packages numpy pandas matplotlib etc**

# %% [markdown]
# ![](2024-07-30-23-35-18.png)

# %% [markdown]
# ![](2024-07-30-23-38-03.png)

# %% [markdown]
#  ### **data analysis packages**

# %% [markdown]
# ![](2024-07-30-23-39-28.png)

# %% [markdown]
#  ### **machine learning deep learning and ai pytorch tensorflow**

# %% [markdown]
# ![](2024-07-30-23-42-14.png)

# %% [markdown]
#  ### **python web frameworks**

# %% [markdown]
# ![](2024-07-30-23-43-34.png)

# %% [markdown]
# ![](2024-07-30-23-44-21.png)

# %% [markdown]
# **Full-Stack**

# %% [markdown]
# ![](2024-07-30-23-47-14.png)

# %% [markdown]
# ![](2024-07-30-23-47-31.png)

# %% [markdown]
# **Microframeworks**

# %% [markdown]
# ![](2024-07-30-23-47-50.png)

# %% [markdown]
# **Asynchronous**

# %% [markdown]
# ![](2024-07-30-23-48-12.png)

# %% [markdown]
# ## **Testing Tools**

# %% [markdown]
#  ### **what is testing**

# %% [markdown]
# ![](2024-07-30-23-51-28.png)

# %% [markdown]
# ![](2024-07-30-23-52-11.png)

# %% [markdown]
#  ### **types of testing**

# %% [markdown]
# ![](2024-07-30-23-52-58.png)

# %% [markdown]
# ![](2024-07-30-23-53-37.png)

# %% [markdown]
# ![](2024-07-30-23-54-17.png)

# %% [markdown]
#  ![](2024-07-30-23-55-23.png)

# %% [markdown]
# ![](2024-07-30-23-56-21.png)

# %% [markdown]
#  ### **test automation packages**

# %% [markdown]
# ![](2024-07-30-23-58-14.png)

# %% [markdown]
# ![](2024-07-30-23-58-57.png)

# %% [markdown]
# ![](2024-07-30-23-59-34.png)

# %% [markdown]
#  ### **writing tests with pytest**

# %% [markdown]
# ![](2024-07-31-00-01-37.png)

# %% [markdown]
# ![](2024-07-31-00-02-17.png)

# %% [markdown]
# ![](2024-07-31-00-03-19.png)

# %% [markdown]
# ![](2024-07-31-00-05-00.png)

# %% [markdown]
# ![](2024-07-31-00-09-35.png)

# %% [markdown]
#  ### **test driven development tdd**

# %% [markdown]
# ![](2024-07-31-00-10-33.png)

# %% [markdown]
# ![](2024-07-31-00-11-30.png)

# %% [markdown]
#  ### **applying tdd**

# %% [markdown]
# ![](2024-07-31-00-13-28.png)

# %% [markdown]
# ![](2024-07-31-00-17-10.png)
