# %% [markdown]
# ## **Getting Started with AWS Cloud**

# %% [markdown]
# ### **The Command Line**

# %% [markdown]
# ![](2024-07-26-02-46-31.png)

# %% [markdown]
# ![](2024-07-26-02-47-10.png)

# %% [markdown]
# ![](2024-07-26-02-48-11.png)

# %% [markdown]
# ![](2024-07-26-02-49-43.png)

# %% [markdown]
# ![](2024-07-26-02-50-45.png)

# %% [markdown]
# ![](2024-07-26-02-51-37.png)

# %% [markdown]
# ### **Unix Commands**

# %% [markdown]
# ![](2024-07-26-02-54-05.png)

# %% [markdown]
# ![](2024-07-26-02-54-53.png)

# %% [markdown]
# ### **Bash on Windows**

# %% [markdown]
# ![](2024-07-26-02-57-22.png)

# %% [markdown]
# ![](2024-07-26-02-59-48.png)

# %% [markdown]
# ![](2024-07-26-03-01-59.png)

# %% [markdown]
# ![](2024-07-26-03-02-29.png)

# %% [markdown]
# making testshell.sh executable ...

# %% [markdown]
# ![](2024-07-26-03-03-34.png)

# %% [markdown]
# ![](2024-07-26-03-04-02.png)

# %% [markdown]
# ![](2024-07-26-03-05-23.png)

# %% [markdown]
# ### **Change Directories and List Contents**

# %% [markdown]
# ### **Creating and Moving Directories and Files**

# %% [markdown]
# ![](2024-07-26-03-09-29.png)

# %% [markdown]
# ![](2024-07-26-03-17-30.png)

# %% [markdown]
# ![](2024-07-26-03-31-59.png)

# %% [markdown]
# ### **Pipes**

# %% [markdown]
# ![](2024-07-26-03-33-36.png)

# %% [markdown]
# ![](2024-07-26-03-34-42.png)

# %% [markdown]
# ![](2024-07-26-03-35-23.png)

# %% [markdown]
# ### **Redirection**

# %% [markdown]
# ![](2024-07-26-03-36-03.png)

# %% [markdown]
# ![](2024-07-26-03-36-23.png)

# %% [markdown]
# ![](2024-07-26-03-36-49.png)

# %% [markdown]
# ![](2024-07-26-03-37-33.png)

# %% [markdown]
# ![](2024-07-26-03-38-45.png)

# %% [markdown]
# ![](2024-07-26-03-39-12.png)

# %% [markdown]
# ![](2024-07-26-03-39-45.png)

# %% [markdown]
# ![](2024-07-26-03-40-47.png)

# %% [markdown]
# ![](2024-07-26-03-41-27.png)

# %% [markdown]
# ![](2024-07-26-03-42-19.png)

# %% [markdown]
# ![](2024-07-26-03-42-54.png)

# %% [markdown]
# ![](2024-07-26-03-44-07.png)

# %% [markdown]
# ![](2024-07-26-03-44-43.png)

# %% [markdown]
# ![](2024-07-26-03-45-07.png)

# %% [markdown]
# ![](2024-07-26-03-45-49.png)

# %% [markdown]
# ![](2024-07-26-03-46-04.png)

# %% [markdown]
# ![](2024-07-26-03-46-22.png)

# %% [markdown]
# ### **Grep**

# %% [markdown]
#  ![](2024-07-26-03-47-17.png)

# %% [markdown]
# ![](2024-07-26-03-47-38.png)

# %% [markdown]
# ![](2024-07-26-03-48-02.png)

# %% [markdown]
# ![](2024-07-26-03-48-20.png)

# %% [markdown]
# ![](2024-07-26-03-48-50.png)

# %% [markdown]
# ![](2024-07-26-03-49-22.png)

# %% [markdown]
# ![](2024-07-26-03-50-15.png)
