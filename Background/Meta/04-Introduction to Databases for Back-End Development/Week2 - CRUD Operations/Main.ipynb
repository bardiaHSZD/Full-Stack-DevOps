# %% [markdown]
# ## **SQL Data Types**

# %% [markdown]
# ![](2024-07-27-01-01-57.png)

# %% [markdown]
# ![](2024-07-27-01-02-54.png)

# %% [markdown]
# ![](2024-07-27-01-03-17.png)

# %% [markdown]
# ![](2024-07-27-01-04-29.png)

# %% [markdown]
# ![](2024-07-27-01-05-41.png)

# %% [markdown]
# ![](2024-07-27-01-05-26.png)

# %% [markdown]
# ![](2024-07-27-01-06-23.png)

# %% [markdown]
# ![](2024-07-27-01-06-53.png)

# %% [markdown]
# ![](2024-07-27-01-07-31.png)

# %% [markdown]
# ![](2024-07-27-01-08-48.png)

# %% [markdown]
# ![](2024-07-27-01-09-39.png)

# %% [markdown]
# ![](2024-07-27-01-14-34.png)

# %% [markdown]
# ![](2024-07-27-01-15-07.png)

# %% [markdown]
# ![](2024-07-27-01-17-10.png)

# %% [markdown]
# ![](2024-07-27-01-17-32.png)

# %% [markdown]
# ![](2024-07-27-01-17-54.png)

# %% [markdown]
# ![](2024-07-27-01-18-21.png)

# %% [markdown]
# ![](2024-07-27-01-19-28.png)

# %% [markdown]
# ![](2024-07-27-01-20-03.png)

# %% [markdown]
# ![](2024-07-27-01-20-43.png)

# %% [markdown]
# ![](2024-07-27-01-21-26.png)

# %% [markdown]
# ## **Create and Read**

# %% [markdown]
# ### **Create and Drop Databases**

# %% [markdown]
# ![](2024-07-27-01-29-50.png)

# %% [markdown]
# ![](2024-07-27-01-30-10.png)

# %% [markdown]
# ![](2024-07-27-01-30-52.png)

# %% [markdown]
# ![](2024-07-27-01-44-03.png)

# %% [markdown]
# ![](2024-07-27-01-44-48.png)

# %% [markdown]
# ![](2024-07-27-01-45-22.png)

# %% [markdown]
# ![](2024-07-27-01-45-46.png)

# %% [markdown]
# ### **Create Table Statement**

# %% [markdown]
# ![](2024-07-27-02-04-06.png)

# %% [markdown]
# ![](2024-07-27-02-05-07.png)

# %% [markdown]
# ### **Alter Table Statement**

# %% [markdown]
# ![](2024-07-27-02-06-15.png)

# %% [markdown]
# ![](2024-07-27-02-07-32.png)

# %% [markdown]
# ![](2024-07-27-02-08-07.png)

# %% [markdown]
# ![](2024-07-27-02-08-40.png)

# %% [markdown]
# ![](2024-07-27-02-09-14.png)

# %% [markdown]
# ### **Insert Statement**

# %% [markdown]
# ![](2024-07-27-02-10-16.png)

# %% [markdown]
# ![](2024-07-27-02-10-44.png)

# %% [markdown]
# ![](2024-07-27-02-12-22.png)

# %% [markdown]
# ![](2024-07-27-02-13-17.png)

# %% [markdown]
# ![](2024-07-27-02-14-12.png)

# %% [markdown]
# ![](2024-07-27-02-16-00.png)

# %% [markdown]
# ![](2024-07-27-02-16-22.png)

# %% [markdown]
# ![](2024-07-27-02-26-32.png)

# %% [markdown]
# ![](2024-07-27-02-26-50.png)

# %% [markdown]
# ### **Select Statement**

# %% [markdown]
# ![](2024-07-27-02-27-54.png)

# %% [markdown]
# ![](2024-07-27-02-28-29.png)

# %% [markdown]
# ![](2024-07-27-02-29-01.png)

# %% [markdown]
# ![](2024-07-27-02-29-35.png)

# %% [markdown]
# ![](2024-07-27-02-29-50.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](2024-07-27-02-31-01.png)

# %% [markdown]
# ![](2024-07-27-02-30-34.png)

# %% [markdown]
# ### **Insert Into Select Statement**

# %% [markdown]
# ![](2024-07-27-02-31-49.png)

# %% [markdown]
# ![](2024-07-27-02-32-18.png)

# %% [markdown]
# ![](2024-07-27-02-33-28.png)

# %% [markdown]
# ![](2024-07-27-02-33-46.png)

# %% [markdown]
# ## **Update and Delete**

# %% [markdown]
# ### **Update Data**

# %% [markdown]
# ![](2024-07-27-02-37-47.png)

# %% [markdown]
# ![](2024-07-27-02-38-58.png)

# %% [markdown]
# ![](2024-07-27-02-39-18.png)

# %% [markdown]
# ![](2024-07-27-02-40-19.png)

# %% [markdown]
# ![](2024-07-27-02-40-47.png)

# %% [markdown]
# ![](2024-07-27-02-41-23.png)

# %% [markdown]
# ### **Delete Data**

# %% [markdown]
# ![](2024-07-27-02-41-48.png)

# %% [markdown]
# ![](2024-07-27-02-42-20.png)

# %% [markdown]
# ![](2024-07-27-02-42-51.png)

# %% [markdown]
# ![](2024-07-27-02-43-32.png)

# %% [markdown]
# ![](2024-07-27-02-44-01.png)

# %% [markdown]
# ![](2024-07-27-02-44-38.png)

# %% [markdown]
# ![](2024-07-27-02-44-55.png)
