# %% [markdown]
# ## **Course Introduction**

# %% [markdown]
# ![](2024-07-26-23-37-00.png)

# %% [markdown]
# ![](2024-07-26-23-38-02.png)

# %% [markdown]
# ![](2024-07-26-23-38-26.png)

# %% [markdown]
# ![](2024-07-26-23-39-43.png)

# %% [markdown]
# ![](2024-07-26-23-39-22.png)

# %% [markdown]
# ## **Databases and Data**

# %% [markdown]
# ![](2024-07-26-23-46-00.png)

# %% [markdown]
# ![](2024-07-26-23-47-24.png)

# %% [markdown]
# ![](2024-07-26-23-48-47.png)

# %% [markdown]
# ![](2024-07-26-23-49-27.png)

# %% [markdown]
# ![](2024-07-26-23-49-47.png)

# %% [markdown]
# ![](2024-07-26-23-50-28.png)

# %% [markdown]
# ![](2024-07-26-23-50-55.png)

# %% [markdown]
# ![](2024-07-26-23-52-02.png)

# %% [markdown]
# ![](2024-07-26-23-53-30.png)

# %% [markdown]
# ![](2024-07-26-23-54-14.png)

# %% [markdown]
# ![](2024-07-26-23-54-47.png)

# %% [markdown]
# ![](2024-07-26-23-55-20.png)

# %% [markdown]
# ![](2024-07-26-23-56-16.png)

# %% [markdown]
# ![](2024-07-26-23-56-43.png)

# %% [markdown]
# ![](2024-07-26-23-57-41.png)

# %% [markdown]
# ![](2024-07-26-23-58-32.png)

# %% [markdown]
# ![](2024-07-26-23-59-10.png)

# %% [markdown]
# ![](2024-07-27-00-00-20.png)

# %% [markdown]
# ![](2024-07-27-00-00-45.png)

# %% [markdown]
# ![](2024-07-27-00-01-11.png)

# %% [markdown]
# ![](2024-07-27-00-01-47.png)

# %% [markdown]
# ![](2024-07-27-00-02-33.png)

# %% [markdown]
# ![](2024-07-27-00-02-56.png)

# %% [markdown]
# ## **Intro to SQL**

# %% [markdown]
# ### **What is SQL?**

# %% [markdown]
# ![](2024-07-27-00-07-00.png)

# %% [markdown]
# ![](2024-07-27-00-07-34.png)

# %% [markdown]
# ![](2024-07-27-00-08-04.png)

# %% [markdown]
# ![](2024-07-27-00-08-36.png)

# %% [markdown]
# ### **SQL Usage**

# %% [markdown]
# ![](2024-07-27-00-10-14.png)

# %% [markdown]
# ![](2024-07-27-00-11-01.png)

# %% [markdown]
# ![](2024-07-27-00-14-26.png)

# %% [markdown]
# ![](2024-07-27-00-14-57.png)

# %% [markdown]
# ![](2024-07-27-00-17-22.png)

# %% [markdown]
# ![](2024-07-27-00-17-50.png)

# %% [markdown]
# ![](2024-07-27-00-18-22.png)

# %% [markdown]
# ![](2024-07-27-00-19-11.png)

# %% [markdown]
# ![](2024-07-27-00-19-53.png)

# %% [markdown]
# ![](2024-07-27-00-20-19.png)

# %% [markdown]
# ### **Advantages of SQL**

# %% [markdown]
# ![](2024-07-27-00-21-08.png)

# %% [markdown]
# ![](2024-07-27-00-22-12.png)

# %% [markdown]
# ![](2024-07-27-00-22-42.png)

# %% [markdown]
# ### **SQL Syntax Introduction**

# %% [markdown]
# ![](2024-07-27-00-29-24.png)

# %% [markdown]
# ![](2024-07-27-00-30-00.png)

# %% [markdown]
# ![](2024-07-27-00-30-47.png)

# %% [markdown]
# ![](2024-07-27-00-31-19.png)

# %% [markdown]
# ![](2024-07-27-00-32-13.png)

# %% [markdown]
# ![](2024-07-27-00-33-24.png)

# %% [markdown]
# ![](2024-07-27-00-35-26.png)

# %% [markdown]
# ## **Basic Database Structure**

# %% [markdown]
# ![](2024-07-27-00-38-19.png)

# %% [markdown]
# ![](2024-07-27-00-38-57.png)

# %% [markdown]
# ![](2024-07-27-00-39-58.png)

# %% [markdown]
# ![](2024-07-27-00-41-11.png)

# %% [markdown]
# ![](2024-07-27-00-42-56.png)

# %% [markdown]
# ![](2024-07-27-00-43-26.png)

# %% [markdown]
# ![](2024-07-27-00-44-12.png)

# %% [markdown]
# ![](2024-07-27-00-44-49.png)

# %% [markdown]
# ![](2024-07-27-00-45-32.png)

# %% [markdown]
# ![](2024-07-27-00-46-17.png)
