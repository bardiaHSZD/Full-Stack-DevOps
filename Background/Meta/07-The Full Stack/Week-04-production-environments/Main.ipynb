# %% [markdown]
# ## **Web Server Environments**

# %% [markdown]
# #### **server and serverless**

# %% [markdown]
# ![](2024-08-12-00-16-42.png)

# %% [markdown]
# ![](2024-08-12-00-17-00.png)

# %% [markdown]
# ![](2024-08-12-00-17-23.png)

# %% [markdown]
# > Automatic Deployment ...

# %% [markdown]
# ![](2024-08-12-00-18-03.png)

# %% [markdown]
# ![](2024-08-12-00-18-22.png)

# %% [markdown]
# ![](2024-08-12-00-19-08.png)

# %% [markdown]
# ![](2024-08-12-00-19-44.png)

# %% [markdown]
# ![](2024-08-12-00-20-24.png)

# %% [markdown]
# ![](2024-08-12-00-20-49.png)

# %% [markdown]
# > Tools for these steps include Jenkins, Circle CI, Github's CI Actions.

# %% [markdown]
# ![](2024-08-12-00-22-39.png)

# %% [markdown]
# ##### **Server Approach**

# %% [markdown]
# ![](2024-08-12-00-24-00.png)

# %% [markdown]
# ![](2024-08-12-00-24-21.png)

# %% [markdown]
# > Dedicated Servers

# %% [markdown]
# ![](2024-08-12-00-24-48.png)

# %% [markdown]
# ![](2024-08-12-00-25-02.png)

# %% [markdown]
# > Virtual Servers

# %% [markdown]
# ![](2024-08-12-00-25-35.png)

# %% [markdown]
# ![](2024-08-12-00-26-35.png)

# %% [markdown]
# ![](2024-08-12-00-27-04.png)

# %% [markdown]
# For example, one deals with the application server and the other one deals with the database. However, this requires significant management and effort.

# %% [markdown]
# ##### **Serverless Approach**

# %% [markdown]
# ![](2024-08-12-00-28-40.png)

# %% [markdown]
# ![](2024-08-12-00-31-16.png)

# %% [markdown]
# ![](2024-08-12-00-31-48.png)

# %% [markdown]
# ![](2024-08-12-00-32-10.png)

# %% [markdown]
# ![](2024-08-12-00-32-49.png)

# %% [markdown]
# **Note:** Any unmmonitored consumption could result in big spikes in costs.

# %% [markdown]
# ![](2024-08-12-00-34-24.png)

# %% [markdown]
# ![](2024-08-12-00-34-52.png)

# %% [markdown]
# So moving apps to another provider requires code changes.

# %% [markdown]
# #### **virtual machines and containerization**

# %% [markdown]
# ![](2024-08-12-00-36-36.png)

# %% [markdown]
# ![](2024-08-12-00-37-00.png)

# %% [markdown]
# ![](2024-08-12-00-37-25.png)

# %% [markdown]
# ![](2024-08-12-00-38-04.png)

# %% [markdown]
# Type-1 hypervisor is also called bare-metal hypervisor.

# %% [markdown]
# ![](2024-08-12-00-39-29.png)

# %% [markdown]
# Therefore, ther are more efficient in resource management. The applications that run on type-1 hypervisors are usually faster, because they have dedicated resources.

# %% [markdown]
# ![](2024-08-12-00-42-10.png)

# %% [markdown]
# ![](2024-08-12-00-49-10.png)

# %% [markdown]
# ![](2024-08-12-00-49-36.png)

# %% [markdown]
# ![](2024-08-12-00-49-57.png)

# %% [markdown]
# ![](2024-08-12-00-50-28.png)

# %% [markdown]
# ![](2024-08-12-00-50-56.png)

# %% [markdown]
# The problem is that the allocated memory cannot be used by other VMs, even if it is not bein used.

# %% [markdown]
# ![](2024-08-12-00-52-44.png)

# %% [markdown]
# However,

# %% [markdown]
# ![](2024-08-12-00-53-19.png)

# %% [markdown]
# > Another solution is to remove hardware and operating system from the equation. And, focus only on the applciation and dependencies.

# %% [markdown]
# ![](2024-08-12-00-56-39.png)

# %% [markdown]
# ![](2024-08-12-00-56-53.png)

# %% [markdown]
# ![](2024-08-12-00-57-10.png)

# %% [markdown]
# ![](2024-08-12-00-57-28.png)

# %% [markdown]
# ![](2024-08-12-00-58-24.png)

# %% [markdown]
# ![](2024-08-12-00-59-21.png)

# %% [markdown]
# ![](2024-08-12-01-00-01.png)

# %% [markdown]
# ![](2024-08-12-01-01-33.png)

# %% [markdown]
# ![](2024-08-12-01-01-57.png)

# %% [markdown]
# ![](2024-08-12-01-03-58.png)

# %% [markdown]
# ![](2024-08-12-01-04-31.png)

# %% [markdown]
# ![](2024-08-12-01-04-52.png)

# %% [markdown]
# ## **Introduction to Cloud Computing**

# %% [markdown]
# #### **what is cloud computing**

# %% [markdown]
# ![](2024-08-12-01-29-59.png)

# %% [markdown]
# ![](2024-08-12-01-30-30.png)

# %% [markdown]
# ![](2024-08-12-01-30-57.png)

# %% [markdown]
# ![](2024-08-12-01-37-19.png)

# %% [markdown]
# ![](2024-08-12-01-38-36.png)

# %% [markdown]
# ![](2024-08-12-01-38-55.png)

# %% [markdown]
# Using public clouds starts cheap, but it gets more expensive as it grows.

# %% [markdown]
# ![](2024-08-12-01-40-14.png)

# %% [markdown]
# ![](2024-08-12-01-40-56.png)

# %% [markdown]
# ![](2024-08-12-01-41-18.png)

# %% [markdown]
# Since everything is hosted and managed by yourself, it can be costly at start.

# %% [markdown]
# ![](2024-08-12-01-42-54.png)

# %% [markdown]
# ![](2024-08-12-01-43-15.png)

# %% [markdown]
# ![](2024-08-12-01-43-43.png)

# %% [markdown]
# #### **key elements of cloud computing**

# %% [markdown]
# ![](2024-08-12-01-44-47.png)

# %% [markdown]
# ![](2024-08-12-01-45-22.png)

# %% [markdown]
# ![](2024-08-12-01-45-41.png)

# %% [markdown]
# ![](2024-08-12-01-46-16.png)

# %% [markdown]
# ![](2024-08-12-01-46-57.png)

# %% [markdown]
# ![](2024-08-12-01-47-28.png)

# %% [markdown]
# The given URL for from your data on an object storage will be automatically expire, based on the time stamp signature assigned.

# %% [markdown]
# ![](2024-08-12-01-49-13.png)

# %% [markdown]
# ![](2024-08-12-01-49-48.png)

# %% [markdown]
# ![](2024-08-12-01-50-09.png)

# %% [markdown]
# ![](2024-08-12-01-50-31.png)

# %% [markdown]
# ![](2024-08-12-01-51-01.png)

# %% [markdown]
# ![](2024-08-12-01-51-24.png)

# %% [markdown]
# ![](2024-08-12-01-51-47.png)

# %% [markdown]
# ## **Scaling in the Cloud**

# %% [markdown]
# #### **what is scaling**

# %% [markdown]
# ![](2024-08-12-02-03-20.png)

# %% [markdown]
# ![](2024-08-12-02-03-40.png)

# %% [markdown]
# ![](2024-08-12-02-04-00.png)

# %% [markdown]
# ![](2024-08-12-02-04-26.png)

# %% [markdown]
# ![](2024-08-12-02-04-56.png)

# %% [markdown]
# ![](2024-08-12-02-05-26.png)

# %% [markdown]
# if one webserver can handle 2000 requests, to handle 10,000 requests we need 4X webservers.

# %% [markdown]
# ![](2024-08-12-02-07-30.png)

# %% [markdown]
# ![](2024-08-12-02-07-54.png)

# %% [markdown]
# ![](2024-08-12-02-08-24.png)

# %% [markdown]
# #### **load balancing**

# %% [markdown]
# ![](2024-08-12-02-09-16.png)

# %% [markdown]
# ![](2024-08-12-02-09-41.png)

# %% [markdown]
# ![](2024-08-12-02-15-29.png)

# %% [markdown]
# ![](2024-08-12-02-16-01.png)

# %% [markdown]
# ![](2024-08-12-02-16-23.png)

# %% [markdown]
# On a reound-roubin, the load balancer equaly assigns the loads. But, there is a problem. Not all requests are the same. Some take a fraction of a second to finish. Also, on a round-robin fashion some servers that are already processing request may recieve subsequent requests. This problem is resolved with Health-based approach.

# %% [markdown]
# ![](2024-08-12-02-19-50.png)

# %% [markdown]
# ![](2024-08-12-02-20-10.png)

# %% [markdown]
# ![](2024-08-12-02-21-03.png)

# %% [markdown]
# ![](2024-08-12-02-21-26.png)

# %% [markdown]
# Similarly,

# %% [markdown]
# ![](2024-08-12-02-21-52.png)

# %% [markdown]
# ![](2024-08-12-02-22-14.png)

# %% [markdown]
# For databases ...

# %% [markdown]
# ![](2024-08-12-02-22-45.png)

# %% [markdown]
# For horizontal scaling, there two methods:

# %% [markdown]
# ![](2024-08-12-02-23-52.png)

# %% [markdown]
# ![](2024-08-12-02-24-27.png)

# %% [markdown]
# ![](2024-08-12-02-24-46.png)

# %% [markdown]
# ![](2024-08-12-02-25-30.png)

# %% [markdown]
# micro-services communicate with each other over private IP addresses.
